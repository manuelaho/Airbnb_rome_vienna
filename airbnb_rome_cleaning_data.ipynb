# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_theme()

pd.set_option('display.max_rows', 25)          
pd.set_option('display.max_columns', 100)      
pd.set_option('display.width', None)             
pd.set_option('display.max_colwidth', 100)       
pd.set_option("display.precision", 6)

# %%
df_rome = pd.read_csv("rom_airbnb_listings.csv")

# %%
df_rome.head(3)
# Out:
#       id                                                           name  \
# 0  75474               Villa in Rome · 9 bedrooms · 10 beds · 6.5 baths
# 1   2737  Place to stay in Rome · ★4.80 · 1 bedroom · 1 bed · 1.5 baths
# 2   3079       Rental unit in Rome · ★4.53 · 1 bedroom · 1 bed · 1 bath
#
#    host_id host_name  neighbourhood_group      neighbourhood  latitude  \
# 0   400717    Marina                  NaN    III Monte Sacro  41.98959
# 1     3047      Elif                  NaN  VIII Appia Antica  41.87136
# 2     3504     Laura                  NaN   I Centro Storico  41.89500
#
#    longitude        room_type   price  minimum_nights  number_of_reviews  \
# 0   12.52154  Entire home/apt  1973.0               3                  2
# 1   12.48215     Private room    50.0               7                  5
# 2   12.49117  Entire home/apt   120.0              30                 21
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2023-06-20               0.31                               1
# 1  2015-05-08               0.05                               6
# 2  2022-04-30               0.13                               6
#
#    availability_365  number_of_reviews_ltm license
# 0               332                      2     NaN
# 1               345                      0     NaN
# 2               289                      0     NaN

# %%
df_rome.nunique()
# Out:
# id                                29357
# name                               9263
# host_id                           15645
# host_name                          3648
# neighbourhood_group                   0
# neighbourhood                        15
# latitude                          16230
# longitude                         18566
# room_type                             4
# price                               871
# minimum_nights                       52
# number_of_reviews                   585
# last_review                        1813
# reviews_per_month                   825
# calculated_host_listings_count       47
# availability_365                    366
# number_of_reviews_ltm               137
# license                            5711
# dtype: int64

# %%
df_rome.shape
# Out:
# (29357, 18)

# %%
df_rome.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29357 entries, 0 to 29356
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              29357 non-null  int64
#  1   name                            29357 non-null  object
#  2   host_id                         29357 non-null  int64
#  3   host_name                       29348 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   29357 non-null  object
#  6   latitude                        29357 non-null  float64
#  7   longitude                       29357 non-null  float64
#  8   room_type                       29357 non-null  object
#  9   price                           27381 non-null  float64
#  10  minimum_nights                  29357 non-null  int64
#  11  number_of_reviews               29357 non-null  int64
#  12  last_review                     25086 non-null  object
#  13  reviews_per_month               25086 non-null  float64
#  14  calculated_host_listings_count  29357 non-null  int64
#  15  availability_365                29357 non-null  int64
#  16  number_of_reviews_ltm           29357 non-null  int64
#  17  license                         6793 non-null   object
# dtypes: float64(5), int64(7), object(6)
# memory usage: 4.0+ MB

# %%
df_rome.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  2.935700e+04  2.935700e+04                  0.0  29357.000000
# mean   3.411734e+17  1.701936e+08                  NaN     41.891868
# std    4.223487e+17  1.804467e+08                  NaN      0.035648
# min    2.737000e+03  1.944000e+03                  NaN     41.656792
# 25%    2.014628e+07  2.042828e+07                  NaN     41.885448
# 50%    4.569450e+07  8.683540e+07                  NaN     41.896580
# 75%    8.120685e+17  2.975611e+08                  NaN     41.906480
# max    1.046345e+18  5.508256e+08                  NaN     42.121310
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  29357.000000  27381.000000    29357.000000       29357.000000
# mean      12.480778    172.378912        3.213714          55.229145
# std        0.048908    712.298687       16.044470          89.375230
# min       12.238500      8.000000        1.000000           0.000000
# 25%       12.461160     76.000000        1.000000           3.000000
# 50%       12.477890    105.000000        2.000000          18.000000
# 75%       12.504410    157.000000        3.000000          68.000000
# max       12.835699  80000.000000      999.000000        1879.000000
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# count       25086.000000                    29357.000000      29357.000000
# mean            1.721920                        9.096468        184.374187
# std             1.671394                       29.698329        132.577118
# min             0.010000                        1.000000          0.000000
# 25%             0.400000                        1.000000         50.000000
# 50%             1.210000                        2.000000        196.000000
# 75%             2.600000                        6.000000        314.000000
# max            38.560000                      265.000000        365.000000
#
#        number_of_reviews_ltm
# count           29357.000000
# mean               15.867868
# std                21.009852
# min                 0.000000
# 25%                 0.000000
# 50%                 6.000000
# 75%                25.000000
# max               601.000000

# %% [markdown]
# # Null values

# %%
df_rome.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             9
# neighbourhood_group               29357
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              1976
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        4271
# reviews_per_month                  4271
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           22564
# dtype: int64

# %%
# Delete features "neighbourhood_group" and "license"

df_rome.drop("neighbourhood_group", axis=1, inplace=True)

df_rome.drop("license", axis=1, inplace=True)

# %%
# Delete feature "last_review"

df_rome.drop("last_review", axis=1, inplace=True)

# %%
# Delete features "id" and "host_id" --> not important for analysies

df_rome.drop("id", axis=1, inplace=True)

df_rome.drop("host_id", axis=1, inplace=True)

# %%
# Delete 9 samples of null values from column "host_name":

df_rome.drop(df_rome[df_rome["host_name"].isnull()].index, inplace=True)

# %%
#Column "price" --> fill null values with "105" --> 50 % price:

df_rome["price"] = df_rome["price"].fillna(105)

# %%
#Column "reviews_per_month" --> fill null values with mean:

df_rome["reviews_per_month"].fillna(df_rome["reviews_per_month"].mean(),inplace=True)

# %% [markdown]
# # Checking outliers

# %%
# Checking price > 10.000:

df_rome[df_rome["price"]  > 10000]

# Delete price > 10.000:
    
df_rome.drop(df_rome[df_rome["price"] > 10000].index, inplace=True)

# %%
# Checking minimum_nights > 30:

df_rome[df_rome["minimum_nights"]  > 30]

# Delete  minimum_nights > 30:
    
df_rome.drop(df_rome[df_rome["minimum_nights"] > 30].index, inplace=True)

# %%
# exporting cleaned dataframe

#df_rome.to_csv("rom_airbnb_listings_cleaned.csv",index=False)

# %%
df_rome.head(3)
# Out:
#                                                             name host_name  \
# 0               Villa in Rome · 9 bedrooms · 10 beds · 6.5 baths    Marina
# 1  Place to stay in Rome · ★4.80 · 1 bedroom · 1 bed · 1.5 baths      Elif
# 2       Rental unit in Rome · ★4.53 · 1 bedroom · 1 bed · 1 bath     Laura
#
#        neighbourhood  latitude  longitude        room_type   price  \
# 0    III Monte Sacro  41.98959   12.52154  Entire home/apt  1973.0
# 1  VIII Appia Antica  41.87136   12.48215     Private room    50.0
# 2   I Centro Storico  41.89500   12.49117  Entire home/apt   120.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               3                  2               0.31
# 1               7                  5               0.05
# 2              30                 21               0.13
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                               1               332                      2
# 1                               6               345                      0
# 2                               6               289                      0
